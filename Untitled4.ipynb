# %%
import pandas as pd
import matplotlib.pyplot as plt
df1 = pd.read_excel("/content/drive/MyDrive/data layering.xlsx")
a = df1["rollno"]
b = df1["name"]
plt.plot(a,b)
plt.xlabel("roll no")
plt.ylabel("name")
plt.title("Students record")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df1 = pd.read_excel("/content/drive/MyDrive/data layering.xlsx")
a = df1["sgpa"]
b = df1["rollno"]
plt.title("Students record")
plt.pie(a, labels=b, autopct='%1.1f%%')
plt.show()
