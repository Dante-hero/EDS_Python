# %%
# Using Python do the following operations
# fetch the details above csv file in list
import csv

data = []

with open('/exam.csv', 'r') as file:
    reader = csv.reader(file)
    next(reader)  # Skip the header row
    for row in reader:
        data.append(row)

print(data)
# Arrange the review of medical shop in ascending order 
sorted_data = sorted(data, key=lambda x: int(x[4]))
print(sorted_data)

# Function to fetch top ten pin codes with reviews greater than or equal to 5
def get_top_pin_codes(details):
    pin_codes = {}
    for row in details:
        pin_code = row[2]
        review = int(row[4])
        if review >= 5:
            if pin_code in pin_codes:
                pin_codes[pin_code] += 1
            else:
                pin_codes[pin_code] = 1

    sorted_pins = sorted(pin_codes.items(), key=lambda x: x[1], reverse=True)
    top_pins = [pin for pin, _ in sorted_pins[:10]]
    return top_pins

print(top_ten_pin_codes)

# Perform one dictionary query 
medical_shops = {
    '1,Antophill': {'Pin Code': '400037', 'Name of Medical Shop': 'xyz medical', 'Review': 5},
    '2,Sion': {'Pin Code': '400038', 'Name of Medical Shop': 'abc medical', 'Review': 4},
    '3,Bandra': {'Pin Code': '400039', 'Name of Medical Shop': 'cde medical', 'Review': 5},
    '4,Worli': {'Pin Code': '400040', 'Name of Medical Shop': 'efg medical', 'Review': 5},
    '5,Alandi': {'Pin Code': '400037', 'Name of Medical Shop': 'ghi medical', 'Review': 4},
    '6,Alandi': {'Pin Code': '400041', 'Name of Medical Shop': 'ijk medical', 'Review': 2},
    '7,Alandi': {'Pin Code': '400041', 'Name of Medical Shop': 'klm medical', 'Review': 3},
    '8,Pimpri': {'Pin Code': '400039', 'Name of Medical Shop': 'mno medical', 'Review': 5},
    '9,Dehu': {'Pin Code': '400045', 'Name of Medical Shop': 'opq medical', 'Review': 1},
    '10,Moshi': {'Pin Code': '400046', 'Name of Medical Shop': 'qrs medical', 'Review': 2},
    '11,Bandra': {'Pin Code': '400039', 'Name of Medical Shop': 'stu medical', 'Review': 5},
    '12,Alandi': {'Pin Code': '400041', 'Name of Medical Shop': 'uvx medical', 'Review': 3},
    '13,Malad': {'Pin Code': '400049', 'Name of Medical Shop': 'zyx medical', 'Review': 5},
    '14,Antophill': {'Pin Code': '400050', 'Name of Medical Shop': 'cba medical', 'Review': 6},
    '15,Vashi': {'Pin Code': '400051', 'Name of Medical Shop': 'jko medical', 'Review': 3},
    '16,Kurla': {'Pin Code': '400052', 'Name of Medical Shop': 'ion medical', 'Review': 2},
    '17,Alandi': {'Pin Code': '400041', 'Name of Medical Shop': 'mny medical', 'Review': 4},
    '18,Yerawada': {'Pin Code': '400054', 'Name of Medical Shop': 'afh medical', 'Review': 5},
    '19,Bandra': {'Pin Code': '400039', 'Name of Medical Shop': 'pyh medical', 'Review': 4},
    '20,Dadar': {'Pin Code': '400056', 'Name of Medical Shop': 'hea medical', 'Review': 4}
}

for key, value in medical_shops.items():
    if value['Review'] == 5:
        print(f"Key: {key}, Medical Shop: {value['Name of Medical Shop']}")
# Out:
# [['1', 'Antophill ', '400037', 'xyz medical', '5'], ['2', 'Sion ', '400038', 'abc medical', '4'], ['3', 'Bandra', '400039', 'cde medical', '5'], ['4', 'Worli', '400040', 'efg medical', '5'], ['5', 'Alandi', '400037', 'ghi medical', '4'], ['6', 'Alandi', '400041', 'ijk medical', '2'], ['7', 'Alandi', '400041', 'klm medical', '3'], ['8', 'Pimpri', '400039', 'mno medical', '5'], ['9', 'Dehu', '400045', 'opq medical', '1'], ['10', 'Moshi', '400046', ' qrs medical', '2'], ['11', 'Bandra', '400039', 'stu medical', '5'], ['12', 'Alandi', '400041', 'uvx medical', '3'], ['13', 'Malad', '400049', 'zyx medical', '5'], ['14', 'Antophill ', '400050', 'cba medical', '6'], ['15', 'Vashi', '400051', 'jko medical', '3'], ['16', 'Kurla', '400052', 'ion medical', '2'], ['17', 'Alandi', '400041', 'mny medical', '4'], ['18', 'Yerawada', '400054', 'afh medical', '5'], ['19', 'Bandra', '400039', 'pyh medical', '4'], ['20', 'Dadar', '400056', 'hea medical', '4']]
# ...

# %%
medical_shops = {
    '1,Antophill': {'Pin Code': '400037', 'Name of Medical Shop': 'xyz medical', 'Review': 5},
    '2,Sion': {'Pin Code': '400038', 'Name of Medical Shop': 'abc medical', 'Review': 4},
    '3,Bandra': {'Pin Code': '400039', 'Name of Medical Shop': 'cde medical', 'Review': 5},
    '4,Worli': {'Pin Code': '400040', 'Name of Medical Shop': 'efg medical', 'Review': 5},
    '5,Alandi': {'Pin Code': '400037', 'Name of Medical Shop': 'ghi medical', 'Review': 4},
    '6,Alandi': {'Pin Code': '400041', 'Name of Medical Shop': 'ijk medical', 'Review': 2},
    '7,Alandi': {'Pin Code': '400041', 'Name of Medical Shop': 'klm medical', 'Review': 3},
    '8,Pimpri': {'Pin Code': '400039', 'Name of Medical Shop': 'mno medical', 'Review': 5},
    '9,Dehu': {'Pin Code': '400045', 'Name of Medical Shop': 'opq medical', 'Review': 1},
    '10,Moshi': {'Pin Code': '400046', 'Name of Medical Shop': 'qrs medical', 'Review': 2},
    '11,Bandra': {'Pin Code': '400039', 'Name of Medical Shop': 'stu medical', 'Review': 5},
    '12,Alandi': {'Pin Code': '400041', 'Name of Medical Shop': 'uvx medical', 'Review': 3},
    '13,Malad': {'Pin Code': '400049', 'Name of Medical Shop': 'zyx medical', 'Review': 5},
    '14,Antophill': {'Pin Code': '400050', 'Name of Medical Shop': 'cba medical', 'Review': 6},
    '15,Vashi': {'Pin Code': '400051', 'Name of Medical Shop': 'jko medical', 'Review': 3},
    '16,Kurla': {'Pin Code': '400052', 'Name of Medical Shop': 'ion medical', 'Review': 2},
    '17,Alandi': {'Pin Code': '400041', 'Name of Medical Shop': 'mny medical', 'Review': 4},
    '18,Yerawada': {'Pin Code': '400054', 'Name of Medical Shop': 'afh medical', 'Review': 5},
    '19,Bandra': {'Pin Code': '400039', 'Name of Medical Shop': 'pyh medical', 'Review': 4},
    '20,Dadar': {'Pin Code': '400056', 'Name of Medical Shop': 'hea medical', 'Review': 4}
}

for key, value in medical_shops.items():
    if value['Review'] == 5:
        print(f"Key: {key}, Medical Shop: {value['Name of Medical Shop']}")
