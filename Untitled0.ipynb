# %%
name = input("what is your name?\n")
colour = input("What is your favourite colour?\n")
print(name + " likes " + colour + " colour " )
# Out:
# what is your name?
# Yaseen
# What is your favourite colour?
# green
# Yaseen  likes green  colour

# %%
x = [5,2,5,2,2]
for i in x :
  print(i*'*')
# Out:
# *****
# **
# *****
# **
# **

# %%
name = input("What is your name? ")
print("Assalam Alaikum Wa Rehmatullahi Wa Barakatuh " + name + " Bhaiya")
print("I am going to create a table for your choice:")
x = int(input("Enter your Number? "))
print("Your required table is as follow: ")
for i in range (0,11):
  print(x,'*',i,"=",x*i)
print("Thank You " + name + " Bhaiya!")
print("Assalam Alaikum have a great day Dr. " + name)
# Out:
# What is your name? Ahtesham
# Assalam Alaikum Wa Rehmatullahi Wa Barakatuh Ahtesham Bhaiya
# I am going to create a table for your choice:
# Enter your Number? 50
# Your required table is as follow:
# 50 * 0 = 0
# 50 * 1 = 50
# 50 * 2 = 100
# 50 * 3 = 150
# 50 * 4 = 200
# 50 * 5 = 250
# 50 * 6 = 300
# 50 * 7 = 350
# 50 * 8 = 400
# 50 * 9 = 450
# 50 * 10 = 500
# Thank You Ahtesham Bhaiya!
# Assalam Alaikum have a great day Dr. Ahtesham
